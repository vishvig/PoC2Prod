# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_validate

import warnings
from sklearn.exceptions import ConvergenceWarning, FitFailedWarning

# %%
rs = 1729

# %%
original_df = pd.read_csv(r'../../datasets/imbalanced_dataset/aug_train.csv')[0:10000]
original_df = original_df.loc[:, ~original_df.columns.isin(['id'])]
original_df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   22                1          7.0                   1    < 1 Year
# 1    Male   42                1         28.0                   0    1-2 Year
# 2  Female   66                1         33.0                   0    1-2 Year
# 3  Female   22                1         33.0                   0    < 1 Year
# 4    Male   28                1         46.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0             No          2630.0                 152.0       16         0
# 1            Yes         43327.0                  26.0      135         0
# 2            Yes         35841.0                 124.0      253         0
# 3             No         27645.0                 152.0       69         0
# 4             No         29023.0                 152.0      211         0

# %%
columns = list(original_df.columns)
synthetic_df = pd.read_csv(r'../../datasets/imbalanced_dataset/synthetic.csv')
synthetic_df = synthetic_df[columns]
synthetic_df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   40                1          9.0                   0    1-2 Year
# 1    Male   38                1          3.0                   0   > 2 Years
# 2    Male   38                1         32.0                   0    1-2 Year
# 3  Female   43                1         29.0                   0    1-2 Year
# 4    Male   59                1         10.0                   0    1-2 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes    46994.601769                 124.0      287         1
# 1             No    34303.440793                  26.0      293         0
# 2            Yes    65557.032343                 154.0       73         0
# 3            Yes    64987.866446                 124.0      282         1
# 4            Yes    68556.509949                  26.0      186         1

# %%
predictors = {'categorical': ['Gender', 'Age', 'Driving_License',
                              'Region_Code', 'Previously_Insured', 'Vehicle_Age',
                              'Vehicle_Damage', 'Policy_Sales_Channel', 'Vintage'],
             'continuous': ['Annual_Premium']}
targets = {'categorical': ['Response'],
           'continuous': []}

# %%
from sklearn.preprocessing import LabelEncoder

def to_numpy(df, preds, trgts, encs=None):
    columns = list(df.columns)
    X = np.empty(df[[i for k, v in preds.items() for i in v]].shape)
    Y = np.empty(df[[i for k, v in trgts.items() for i in v]].shape)
    
    for i, col in enumerate(preds['continuous']):
        X[:, columns.index(col)] = df[col]
    for i, col in enumerate(trgts['continuous']):
        Y[:, i] = df[col]
    
    if encs is None:
        encs = dict()
    for i, col in enumerate(preds['categorical']):
        if col not in encs:
            enc = LabelEncoder()
            enc.fit(df[col])
            encs[col] = enc
        else:
            enc = encs[col]
        X[:, columns.index(col)] = enc.transform(df[col])
    for i, col in enumerate(trgts['categorical']):
        if col not in encs:
            enc = LabelEncoder()
            enc.fit(df[col])
            encs[col] = enc
        else:
            enc = encs[col]
        Y[:, i] = enc.transform(df[col])
    
    return X, Y, encs

original_X, original_Y, original_encs = to_numpy(original_df, predictors, targets)
synthetic_X, synthetic_Y, synthetic_encs = to_numpy(synthetic_df, predictors, targets, original_encs)

# %%
OX = np.hstack((original_X, original_Y))
SX = np.hstack((synthetic_X, synthetic_Y))
MX = np.vstack((OX, SX))
print(OX.shape, SX.shape, MX.shape)
# Out:
# (10000, 11) (1000, 11) (11000, 11)

# %%
def to_numpy_x(df, columns):
    """
    Convert dataframe to numpy array by converting categorical variables as integer labels
    :param df: The dataframe to convert
    :param columns: The continuous & discrete columns
    :return: Converted numpy arrays of X & Y and the label encoders
    """

    # declaring empty arrays for the predictor and target variables
    X = np.empty(df[[i for i in columns]].shape)

    # Assign the values from the columns, that are declared continuous,
    # into the corresponding positions in the numpy array
#     for i, col in enumerate(columns):
#         X[:, columns.index(col)] = df[col]

    # Encoding for X (predictors)
    for i, col in enumerate(columns):
        # Initialize, fit and store the label encoder for column
        enc = LabelEncoder()
        enc.fit(df[col])

        # Transform the column using the encoder object
        X[:, columns.index(col)] = enc.transform(df[col])

    return X

# %%
categorical_cols = list()
categorical_cols.extend(predictors['categorical'])
categorical_cols.extend(targets['categorical'])

continuous_cols = list()
continuous_cols.extend(predictors['continuous'])
continuous_cols.extend(targets['continuous'])

original_cat = to_numpy_x(original_df[categorical_cols], categorical_cols)
original_con = original_df[continuous_cols].to_numpy()
syn_cat = to_numpy_x(synthetic_df[categorical_cols], categorical_cols)
syn_con = synthetic_df[continuous_cols].to_numpy()

# %%
# original_clusters = clustering.fit_predict(OX)
# print(original_clusters)

# %%
# mixed_clusters = clustering.fit_predict(MX)
# print(mixed_clusters)

# %%
import math
from sklearn.cluster import AgglomerativeClustering

def log_cluster_metric(X, Xn, n_clusters=2, categorical=False):
    if categorical:
        clusterer = AgglomerativeClustering(n_clusters=n_clusters, affinity='manhattan', linkage='average')
    else:
        clusterer = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='average')
    print(clusterer)
    Xm = np.concatenate((X, Xn), axis=0)
    Na = X.shape[0]
    Nb = Xn.shape[0]
    
    original_labels = clusterer.fit_predict(X)
    merged_labels = clusterer.fit_predict(Xm)
    c = Na / (Na + Nb)
    print(c)

    unique_m, counts_m = np.unique(merged_labels, return_counts=True)
    unique_o, counts_o = np.unique(original_labels, return_counts=True)

    _sum = 0

    for _index, i in enumerate(unique_m):
        _sum += ((counts_m[_index] / counts_o[_index]) - c) ** 2
#     score = math.log(_sum / len(unique_m))
    score = _sum / len(unique_m)
    return score, original_labels, merged_labels


clusters = 5
print(f'Clustering and scoring categorical data')
cat_score, cat_original_labels, cat_merged_labels = log_cluster_metric(original_cat, syn_cat, n_clusters=clusters, categorical=True)
print(f'Clustering and scoring continuous data')
con_score, con_original_labels, con_merged_labels = log_cluster_metric(original_con, syn_con, n_clusters=clusters)
# Out:
# Clustering and scoring categorical data
# AgglomerativeClustering(affinity='manhattan', linkage='average', n_clusters=5)
# 0.9090909090909091
# Clustering and scoring continuous data
# AgglomerativeClustering(linkage='average', n_clusters=5)
# 0.9090909090909091

# %%
print(math.log(np.mean([cat_score, con_score])))
# Out:
# 0.4862190818344094

# %%
corr = original_df.corr('pearson')
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')
 .set_precision(2))
# Out:
# /var/folders/31/zh2tg5jj2wsfynmj9mngmgg80000gn/T/ipykernel_42708/3251293357.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (corr
# <style type="text/css">
# #T_3c355_row0_col0, #T_3c355_row0_col1, #T_3c355_row0_col2, #T_3c355_row0_col3, #T_3c355_row0_col4, #T_3c355_row0_col5, #T_3c355_row0_col6, #T_3c355_row0_col7, #T_3c355_row1_col1, #T_3c355_row1_col2, #T_3c355_row1_col3, #T_3c355_row1_col4, #T_3c355_row1_col5, #T_3c355_row1_col6, #T_3c355_row1_col7, #T_3c355_row2_col2, #T_3c355_row2_col3, #T_3c355_row2_col4, #T_3c355_row2_col5, #T_3c355_row2_col6, #T_3c355_row2_col7, #T_3c355_row3_col3, #T_3c355_row3_col4, #T_3c355_row3_col5, #T_3c355_row3_col6, #T_3c355_row3_col7, #T_3c355_row4_col4, #T_3c355_row4_col5, #T_3c355_row4_col6, #T_3c355_row4_col7, #T_3c355_row5_col5, #T_3c355_row5_col6, #T_3c355_row5_col7, #T_3c355_row6_col6, #T_3c355_row6_col7, #T_3c355_row7_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_3c355_row1_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_3c355_row2_col0, #T_3c355_row5_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_3c355_row2_col1, #T_3c355_row6_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_3c355_row3_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_3c355_row3_col1, #T_3c355_row4_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_3c355_row3_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3c355_row4_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_3c355_row4_col1, #T_3c355_row4_col2, #T_3c355_row6_col0, #T_3c355_row6_col2, #T_3c355_row6_col3, #T_3c355_row7_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_3c355_row5_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_3c355_row5_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_3c355_row5_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_3c355_row5_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_3c355_row6_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_3c355_row6_col5, #T_3c355_row7_col1, #T_3c355_row7_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_3c355_row7_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_3c355_row7_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_3c355_row7_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_3c355_row7_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# </style>
# <table id="T_3c355">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c355_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_3c355_level0_col1" class="col_heading level0 col1" >Driving_License</th>
#       <th id="T_3c355_level0_col2" class="col_heading level0 col2" >Region_Code</th>
#       <th id="T_3c355_level0_col3" class="col_heading level0 col3" >Previously_Insured</th>
#       <th id="T_3c355_level0_col4" class="col_heading level0 col4" >Annual_Premium</th>
#       <th id="T_3c355_level0_col5" class="col_heading level0 col5" >Policy_Sales_Channel</th>
#       <th id="T_3c355_level0_col6" class="col_heading level0 col6" >Vintage</th>
#       <th id="T_3c355_level0_col7" class="col_heading level0 col7" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c355_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_3c355_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_3c355_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_3c355_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_3c355_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_3c355_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_3c355_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_3c355_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_3c355_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row1" class="row_heading level0 row1" >Driving_License</th>
#       <td id="T_3c355_row1_col0" class="data row1 col0" >-0.08</td>
#       <td id="T_3c355_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_3c355_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_3c355_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_3c355_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_3c355_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_3c355_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_3c355_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row2" class="row_heading level0 row2" >Region_Code</th>
#       <td id="T_3c355_row2_col0" class="data row2 col0" >0.05</td>
#       <td id="T_3c355_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_3c355_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_3c355_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_3c355_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_3c355_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_3c355_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_3c355_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row3" class="row_heading level0 row3" >Previously_Insured</th>
#       <td id="T_3c355_row3_col0" class="data row3 col0" >-0.27</td>
#       <td id="T_3c355_row3_col1" class="data row3 col1" >0.02</td>
#       <td id="T_3c355_row3_col2" class="data row3 col2" >-0.03</td>
#       <td id="T_3c355_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_3c355_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_3c355_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_3c355_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_3c355_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row4" class="row_heading level0 row4" >Annual_Premium</th>
#       <td id="T_3c355_row4_col0" class="data row4 col0" >0.05</td>
#       <td id="T_3c355_row4_col1" class="data row4 col1" >-0.00</td>
#       <td id="T_3c355_row4_col2" class="data row4 col2" >-0.00</td>
#       <td id="T_3c355_row4_col3" class="data row4 col3" >0.03</td>
#       <td id="T_3c355_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_3c355_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_3c355_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_3c355_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row5" class="row_heading level0 row5" >Policy_Sales_Channel</th>
#       <td id="T_3c355_row5_col0" class="data row5 col0" >-0.59</td>
#       <td id="T_3c355_row5_col1" class="data row5 col1" >0.05</td>
#       <td id="T_3c355_row5_col2" class="data row5 col2" >-0.05</td>
#       <td id="T_3c355_row5_col3" class="data row5 col3" >0.23</td>
#       <td id="T_3c355_row5_col4" class="data row5 col4" >-0.09</td>
#       <td id="T_3c355_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_3c355_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_3c355_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row6" class="row_heading level0 row6" >Vintage</th>
#       <td id="T_3c355_row6_col0" class="data row6 col0" >-0.01</td>
#       <td id="T_3c355_row6_col1" class="data row6 col1" >0.02</td>
#       <td id="T_3c355_row6_col2" class="data row6 col2" >-0.00</td>
#       <td id="T_3c355_row6_col3" class="data row6 col3" >-0.00</td>
#       <td id="T_3c355_row6_col4" class="data row6 col4" >-0.01</td>
#       <td id="T_3c355_row6_col5" class="data row6 col5" >0.01</td>
#       <td id="T_3c355_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_3c355_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3c355_level0_row7" class="row_heading level0 row7" >Response</th>
#       <td id="T_3c355_row7_col0" class="data row7 col0" >0.13</td>
#       <td id="T_3c355_row7_col1" class="data row7 col1" >0.01</td>
#       <td id="T_3c355_row7_col2" class="data row7 col2" >0.01</td>
#       <td id="T_3c355_row7_col3" class="data row7 col3" >-0.43</td>
#       <td id="T_3c355_row7_col4" class="data row7 col4" >0.01</td>
#       <td

# %%
corr = synthetic_df.corr('pearson')
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')
 .set_precision(2))
# Out:
# /var/folders/31/zh2tg5jj2wsfynmj9mngmgg80000gn/T/ipykernel_42708/2379597370.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (corr
# <style type="text/css">
# #T_54517_row0_col0, #T_54517_row0_col1, #T_54517_row0_col2, #T_54517_row0_col3, #T_54517_row0_col4, #T_54517_row0_col5, #T_54517_row0_col6, #T_54517_row0_col7, #T_54517_row1_col1, #T_54517_row1_col2, #T_54517_row1_col3, #T_54517_row1_col4, #T_54517_row1_col5, #T_54517_row1_col6, #T_54517_row1_col7, #T_54517_row2_col2, #T_54517_row2_col3, #T_54517_row2_col4, #T_54517_row2_col5, #T_54517_row2_col6, #T_54517_row2_col7, #T_54517_row3_col3, #T_54517_row3_col4, #T_54517_row3_col5, #T_54517_row3_col6, #T_54517_row3_col7, #T_54517_row4_col4, #T_54517_row4_col5, #T_54517_row4_col6, #T_54517_row4_col7, #T_54517_row5_col5, #T_54517_row5_col6, #T_54517_row5_col7, #T_54517_row6_col6, #T_54517_row6_col7, #T_54517_row7_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_54517_row1_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_54517_row2_col0, #T_54517_row2_col1, #T_54517_row6_col0, #T_54517_row7_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_54517_row3_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_54517_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_54517_row3_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_54517_row4_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_54517_row4_col1, #T_54517_row4_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_54517_row4_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_54517_row5_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_54517_row5_col1, #T_54517_row6_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_54517_row5_col2, #T_54517_row7_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_54517_row5_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_54517_row5_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_54517_row6_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_54517_row6_col2, #T_54517_row7_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_54517_row6_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_54517_row6_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_54517_row7_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_54517_row7_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_54517_row7_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_54517_row7_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# </style>
# <table id="T_54517">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54517_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_54517_level0_col1" class="col_heading level0 col1" >Driving_License</th>
#       <th id="T_54517_level0_col2" class="col_heading level0 col2" >Region_Code</th>
#       <th id="T_54517_level0_col3" class="col_heading level0 col3" >Previously_Insured</th>
#       <th id="T_54517_level0_col4" class="col_heading level0 col4" >Annual_Premium</th>
#       <th id="T_54517_level0_col5" class="col_heading level0 col5" >Policy_Sales_Channel</th>
#       <th id="T_54517_level0_col6" class="col_heading level0 col6" >Vintage</th>
#       <th id="T_54517_level0_col7" class="col_heading level0 col7" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54517_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_54517_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_54517_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_54517_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_54517_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_54517_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_54517_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_54517_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_54517_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row1" class="row_heading level0 row1" >Driving_License</th>
#       <td id="T_54517_row1_col0" class="data row1 col0" >-0.08</td>
#       <td id="T_54517_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_54517_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_54517_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_54517_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_54517_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_54517_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_54517_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row2" class="row_heading level0 row2" >Region_Code</th>
#       <td id="T_54517_row2_col0" class="data row2 col0" >-0.01</td>
#       <td id="T_54517_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_54517_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_54517_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_54517_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_54517_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_54517_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_54517_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row3" class="row_heading level0 row3" >Previously_Insured</th>
#       <td id="T_54517_row3_col0" class="data row3 col0" >-0.31</td>
#       <td id="T_54517_row3_col1" class="data row3 col1" >-0.03</td>
#       <td id="T_54517_row3_col2" class="data row3 col2" >-0.03</td>
#       <td id="T_54517_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_54517_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_54517_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_54517_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_54517_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row4" class="row_heading level0 row4" >Annual_Premium</th>
#       <td id="T_54517_row4_col0" class="data row4 col0" >0.30</td>
#       <td id="T_54517_row4_col1" class="data row4 col1" >0.02</td>
#       <td id="T_54517_row4_col2" class="data row4 col2" >0.02</td>
#       <td id="T_54517_row4_col3" class="data row4 col3" >-0.21</td>
#       <td id="T_54517_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_54517_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_54517_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_54517_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row5" class="row_heading level0 row5" >Policy_Sales_Channel</th>
#       <td id="T_54517_row5_col0" class="data row5 col0" >-0.49</td>
#       <td id="T_54517_row5_col1" class="data row5 col1" >-0.02</td>
#       <td id="T_54517_row5_col2" class="data row5 col2" >0.02</td>
#       <td id="T_54517_row5_col3" class="data row5 col3" >0.24</td>
#       <td id="T_54517_row5_col4" class="data row5 col4" >-0.21</td>
#       <td id="T_54517_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_54517_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_54517_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row6" class="row_heading level0 row6" >Vintage</th>
#       <td id="T_54517_row6_col0" class="data row6 col0" >-0.00</td>
#       <td id="T_54517_row6_col1" class="data row6 col1" >0.03</td>
#       <td id="T_54517_row6_col2" class="data row6 col2" >0.01</td>
#       <td id="T_54517_row6_col3" class="data row6 col3" >-0.02</td>
#       <td id="T_54517_row6_col4" class="data row6 col4" >-0.02</td>
#       <td id="T_54517_row6_col5" class="data row6 col5" >-0.04</td>
#       <td id="T_54517_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_54517_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_54517_level0_row7" class="row_heading level0 row7" >Response</th>
#       <td id="T_54517_row7_col0" class="data row7 col0" >0.22</td>
#       <td id="T_54517_row7_col1" class="data row7 col1" >0.01</td>
#       <td id="T_54517_row7_col2" class="data row7 col2" >-0.

# %%
print(np.linalg.norm(original_df.corr('pearson')-synthetic_df.corr('pearson')))
# Out:
# 0.6290196949110876
