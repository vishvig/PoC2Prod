# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_validate

import warnings
from sklearn.exceptions import ConvergenceWarning, FitFailedWarning

# %%
rs = 1729

# %%
original_df = pd.read_csv(r'../../datasets/continuous_w_discreteTarget/WineQT.csv')
original_df = original_df.loc[:, ~original_df.columns.isin(['Id'])]
original_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
columns = list(original_df.columns)
synthetic_df = pd.read_csv(r'../../datasets/continuous_w_discreteTarget/synthetic.csv')
synthetic_df = synthetic_df[columns]
synthetic_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       9.582067          0.864727     0.216430        2.695922   0.081322
# 1       8.208484          0.465102     0.028454        3.658549   0.072635
# 2       9.099823          0.663394     0.236752        1.062344   0.093940
# 3       7.569382          0.537020     0.080665        3.241168   0.047722
# 4       5.886650          0.691991    -0.011778        1.188431   0.059731
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             8.063538             15.173011  0.994710  3.252378   0.505812
# 1             9.360043             22.988563  0.994127  3.463537   0.744871
# 2             5.910659             20.380723  0.997278  3.376956   0.793022
# 3             2.577581              5.795272  0.996135  3.382150   0.421073
# 4             4.130674             11.205299  0.995342  3.362238   0.700269
#
#      alcohol  quality
# 0  11.722440        5
# 1  11.866676        5
# 2  11.513966        5
# 3   9.309241        5
# 4  10.308484        5

# %%
predictors = {'categorical': [],
              'continuous': ['fixed acidity', 'volatile acidity', 'citric acid',
              'residual sugar', 'chlorides', 'free sulfur dioxide',
              'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']}
targets = {'categorical': ['quality'],
           'continuous': []}

# %%
from sklearn.preprocessing import LabelEncoder

def to_numpy(df, preds, trgts, encs=None):
    columns = list(df.columns)
    X = np.empty(df[[i for k, v in preds.items() for i in v]].shape)
    Y = np.empty(df[[i for k, v in trgts.items() for i in v]].shape)
    
    for i, col in enumerate(preds['continuous']):
        X[:, columns.index(col)] = df[col]
    for i, col in enumerate(trgts['continuous']):
        Y[:, i] = df[col]
    
    if encs is None:
        encs = dict()
    for i, col in enumerate(preds['categorical']):
        if col not in encs:
            enc = LabelEncoder()
            enc.fit(df[col])
            encs[col] = enc
        else:
            enc = encs[col]
        X[:, columns.index(col)] = enc.transform(df[col])
    for i, col in enumerate(trgts['categorical']):
        if col not in encs:
            enc = LabelEncoder()
            enc.fit(df[col])
            encs[col] = enc
        else:
            enc = encs[col]
        Y[:, i] = enc.transform(df[col])
    
    return X, Y, encs

original_X, original_Y, original_encs = to_numpy(original_df, predictors, targets)
synthetic_X, synthetic_Y, synthetic_encs = to_numpy(synthetic_df, predictors, targets, original_encs)

# %%
OX = np.hstack((original_X, original_Y))
SX = np.hstack((synthetic_X, synthetic_Y))
MX = np.vstack((OX, SX))
print(OX.shape, SX.shape, MX.shape)
# Out:
# (1143, 12) (1000, 12) (2143, 12)

# %%
def to_numpy_x(df, columns):
    """
    Convert dataframe to numpy array by converting categorical variables as integer labels
    :param df: The dataframe to convert
    :param columns: The continuous & discrete columns
    :return: Converted numpy arrays of X & Y and the label encoders
    """

    # declaring empty arrays for the predictor and target variables
    X = np.empty(df[[i for i in columns]].shape)

    # Assign the values from the columns, that are declared continuous,
    # into the corresponding positions in the numpy array
#     for i, col in enumerate(columns):
#         X[:, columns.index(col)] = df[col]

    # Encoding for X (predictors)
    for i, col in enumerate(columns):
        # Initialize, fit and store the label encoder for column
        enc = LabelEncoder()
        enc.fit(df[col])

        # Transform the column using the encoder object
        X[:, columns.index(col)] = enc.transform(df[col])

    return X

# %%
categorical_cols = list()
categorical_cols.extend(predictors['categorical'])
categorical_cols.extend(targets['categorical'])

continuous_cols = list()
continuous_cols.extend(predictors['continuous'])
continuous_cols.extend(targets['continuous'])

original_cat = to_numpy_x(original_df[categorical_cols], categorical_cols)
original_con = original_df[continuous_cols].to_numpy()
syn_cat = to_numpy_x(synthetic_df[categorical_cols], categorical_cols)
syn_con = synthetic_df[continuous_cols].to_numpy()

# %%
# original_clusters = clustering.fit_predict(OX)
# print(original_clusters)

# %%
# mixed_clusters = clustering.fit_predict(MX)
# print(mixed_clusters)

# %%
import math
from sklearn.cluster import AgglomerativeClustering

def log_cluster_metric(X, Xn, n_clusters=2, categorical=False):
    if categorical:
        clusterer = AgglomerativeClustering(n_clusters=n_clusters, affinity='manhattan', linkage='average')
    else:
        clusterer = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='average')
    print(clusterer)
    Xm = np.concatenate((X, Xn), axis=0)
    Na = X.shape[0]
    Nb = Xn.shape[0]
    
    original_labels = clusterer.fit_predict(X)
    merged_labels = clusterer.fit_predict(Xm)
    c = Na / (Na + Nb)
    print(c)

    unique_m, counts_m = np.unique(merged_labels, return_counts=True)
    unique_o, counts_o = np.unique(original_labels, return_counts=True)

    _sum = 0

    for _index, i in enumerate(unique_m):
        _sum += ((counts_m[_index] / counts_o[_index]) - c) ** 2
#     score = math.log(_sum / len(unique_m))
    score = _sum / len(unique_m)
    return score, original_labels, merged_labels


clusters = 20
print(f'Clustering and scoring categorical data')
cat_score, cat_original_labels, cat_merged_labels = log_cluster_metric(original_cat, syn_cat, n_clusters=clusters, categorical=True)
print(f'Clustering and scoring continuous data')
con_score, con_original_labels, con_merged_labels = log_cluster_metric(original_con, syn_con, n_clusters=clusters)
# Out:
# Clustering and scoring categorical data
# AgglomerativeClustering(affinity='manhattan', linkage='average', n_clusters=20)
# 0.5333644423705086
# Clustering and scoring continuous data
# AgglomerativeClustering(linkage='average', n_clusters=20)
# 0.5333644423705086

# %%
print(math.log(np.mean([cat_score, con_score])))
# Out:
# 4.613299539593365

# %%
o_corr = original_df.corr('pearson')
mask = np.zeros_like(o_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
o_corr[mask] = np.nan
(o_corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')
 .set_precision(2))
# Out:
# /var/folders/31/zh2tg5jj2wsfynmj9mngmgg80000gn/T/ipykernel_42799/1090723761.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (o_corr
# <style type="text/css">
# #T_b9a48_row0_col0, #T_b9a48_row0_col1, #T_b9a48_row0_col2, #T_b9a48_row0_col3, #T_b9a48_row0_col4, #T_b9a48_row0_col5, #T_b9a48_row0_col6, #T_b9a48_row0_col7, #T_b9a48_row0_col8, #T_b9a48_row0_col9, #T_b9a48_row0_col10, #T_b9a48_row0_col11, #T_b9a48_row1_col1, #T_b9a48_row1_col2, #T_b9a48_row1_col3, #T_b9a48_row1_col4, #T_b9a48_row1_col5, #T_b9a48_row1_col6, #T_b9a48_row1_col7, #T_b9a48_row1_col8, #T_b9a48_row1_col9, #T_b9a48_row1_col10, #T_b9a48_row1_col11, #T_b9a48_row2_col2, #T_b9a48_row2_col3, #T_b9a48_row2_col4, #T_b9a48_row2_col5, #T_b9a48_row2_col6, #T_b9a48_row2_col7, #T_b9a48_row2_col8, #T_b9a48_row2_col9, #T_b9a48_row2_col10, #T_b9a48_row2_col11, #T_b9a48_row3_col3, #T_b9a48_row3_col4, #T_b9a48_row3_col5, #T_b9a48_row3_col6, #T_b9a48_row3_col7, #T_b9a48_row3_col8, #T_b9a48_row3_col9, #T_b9a48_row3_col10, #T_b9a48_row3_col11, #T_b9a48_row4_col4, #T_b9a48_row4_col5, #T_b9a48_row4_col6, #T_b9a48_row4_col7, #T_b9a48_row4_col8, #T_b9a48_row4_col9, #T_b9a48_row4_col10, #T_b9a48_row4_col11, #T_b9a48_row5_col5, #T_b9a48_row5_col6, #T_b9a48_row5_col7, #T_b9a48_row5_col8, #T_b9a48_row5_col9, #T_b9a48_row5_col10, #T_b9a48_row5_col11, #T_b9a48_row6_col6, #T_b9a48_row6_col7, #T_b9a48_row6_col8, #T_b9a48_row6_col9, #T_b9a48_row6_col10, #T_b9a48_row6_col11, #T_b9a48_row7_col7, #T_b9a48_row7_col8, #T_b9a48_row7_col9, #T_b9a48_row7_col10, #T_b9a48_row7_col11, #T_b9a48_row8_col8, #T_b9a48_row8_col9, #T_b9a48_row8_col10, #T_b9a48_row8_col11, #T_b9a48_row9_col9, #T_b9a48_row9_col10, #T_b9a48_row9_col11, #T_b9a48_row10_col10, #T_b9a48_row10_col11, #T_b9a48_row11_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_b9a48_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b9a48_row2_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_b9a48_row2_col1, #T_b9a48_row8_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b9a48_row3_col0, #T_b9a48_row5_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_b9a48_row3_col1, #T_b9a48_row5_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_b9a48_row3_col2, #T_b9a48_row9_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_b9a48_row4_col0, #T_b9a48_row10_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b9a48_row4_col1, #T_b9a48_row10_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b9a48_row4_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_b9a48_row4_col3, #T_b9a48_row6_col1, #T_b9a48_row8_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b9a48_row5_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b9a48_row5_col2, #T_b9a48_row8_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b9a48_row5_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_b9a48_row6_col0, #T_b9a48_row8_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b9a48_row6_col2, #T_b9a48_row9_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b9a48_row6_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_b9a48_row6_col4, #T_b9a48_row7_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_b9a48_row6_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_b9a48_row7_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_b9a48_row7_col1, #T_b9a48_row9_col3, #T_b9a48_row11_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b9a48_row7_col2, #T_b9a48_row7_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_b9a48_row7_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_b9a48_row7_col5, #T_b9a48_row10_col5, #T_b9a48_row11_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_b9a48_row8_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b9a48_row8_col1, #T_b9a48_row10_col8 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b9a48_row8_col4, #T_b9a48_row9_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b9a48_row8_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b9a48_row9_col2 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b9a48_row9_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_b9a48_row9_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b9a48_row9_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b9a48_row9_col8, #T_b9a48_row11_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b9a48_row10_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b9a48_row10_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_b9a48_row10_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b9a48_row10_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_b9a48_row10_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b9a48_row10_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b9a48_row11_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b9a48_row11_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b9a48_row11_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_b9a48_row11_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_b9a48_row11_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b9a48_row11_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b9a48_row11_col9 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b9a48_row11_col10 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# </style>
# <table id="T_b9a48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9a48_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_b9a48_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_b9a48_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_b9a48_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_b9a48_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_b9a48_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_b9a48_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_b9a48_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_b9a48_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_b9a48_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_b9a48_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_b9a48_level0_col11" class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9a48_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_b9a48_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b9a48_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_b9a48_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b9a48_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_b9a48_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_b9a48_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_b9a48_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_b9a48_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_b9a48_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_b9a48_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_b9a48_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_b9a48_row0_col11" class="data row0 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b9a48_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_b9a48_row1_col0" class="data row1 col0" >-0.25</td>
#       <td id="T_b9a48_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_b9a48_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_b9a48_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_b9a48_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_b9a48_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_b9a48_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_b9a48_row1_col7" class="data row1 col7

# %%
s_corr = synthetic_df.corr('pearson')
mask = np.zeros_like(s_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
s_corr[mask] = np.nan
(s_corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')
 .set_precision(2))
# Out:
# /var/folders/31/zh2tg5jj2wsfynmj9mngmgg80000gn/T/ipykernel_42799/2887317982.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (s_corr
# <style type="text/css">
# #T_f3f0a_row0_col0, #T_f3f0a_row0_col1, #T_f3f0a_row0_col2, #T_f3f0a_row0_col3, #T_f3f0a_row0_col4, #T_f3f0a_row0_col5, #T_f3f0a_row0_col6, #T_f3f0a_row0_col7, #T_f3f0a_row0_col8, #T_f3f0a_row0_col9, #T_f3f0a_row0_col10, #T_f3f0a_row0_col11, #T_f3f0a_row1_col1, #T_f3f0a_row1_col2, #T_f3f0a_row1_col3, #T_f3f0a_row1_col4, #T_f3f0a_row1_col5, #T_f3f0a_row1_col6, #T_f3f0a_row1_col7, #T_f3f0a_row1_col8, #T_f3f0a_row1_col9, #T_f3f0a_row1_col10, #T_f3f0a_row1_col11, #T_f3f0a_row2_col2, #T_f3f0a_row2_col3, #T_f3f0a_row2_col4, #T_f3f0a_row2_col5, #T_f3f0a_row2_col6, #T_f3f0a_row2_col7, #T_f3f0a_row2_col8, #T_f3f0a_row2_col9, #T_f3f0a_row2_col10, #T_f3f0a_row2_col11, #T_f3f0a_row3_col3, #T_f3f0a_row3_col4, #T_f3f0a_row3_col5, #T_f3f0a_row3_col6, #T_f3f0a_row3_col7, #T_f3f0a_row3_col8, #T_f3f0a_row3_col9, #T_f3f0a_row3_col10, #T_f3f0a_row3_col11, #T_f3f0a_row4_col4, #T_f3f0a_row4_col5, #T_f3f0a_row4_col6, #T_f3f0a_row4_col7, #T_f3f0a_row4_col8, #T_f3f0a_row4_col9, #T_f3f0a_row4_col10, #T_f3f0a_row4_col11, #T_f3f0a_row5_col5, #T_f3f0a_row5_col6, #T_f3f0a_row5_col7, #T_f3f0a_row5_col8, #T_f3f0a_row5_col9, #T_f3f0a_row5_col10, #T_f